# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

path="/content/drive/MyDrive/AudioPouring-master/audio_pouring"
os.chdir(path)

# !ls
# Out:
# 2layer_.onnx  demo.py	    model	     __pycache__	utils
# assets	      __init__.py   new.onnx	     run_cnn.ipynb
# config	      main_cnn.py   onnx_demo.ipynb  run_my_lstm.ipynb
# dataset       main_lstm.py  pickle	     Untitled0.ipynb

# %%
# path = ['./dataset/npy_test_1', './dataset/npy_test_3', './dataset/npy_test_4']
# sum = 0
# for i in range(3):
#   file_list = os.listdir(path[i])
#   sum += len(file_list)
# print(sum)

# %%
# path = './dataset/npy_train_4'
# file_list = os.listdir(path)
# print(len(file_list))

# %%
# !python ./model/preprocess_cnn.py test mt
# Out:
# 4s
# pkg_path: /content/drive/MyDrive/AudioPouring-master/audio_pouring
# 1
# 3
# 4
# [ERROR] audio message at 3_2019-01-04-14-06-07.pickle has abnormal message time gaps
# [ERROR] audio message at 3_2018-12-28-13-17-26.pickle is not match time audio ros time
# [ERROR] audio message at 4_2019-01-31-22-48-18.pickle has abnormal message time gaps
# [ERROR] audio message at 4_2019-02-01-07-58-21.pickle has abnormal message time gaps
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
# ...

# %%
# !python ./model/long_preprocess.py test mt

# %%
# !python ./utils/generate_npy_list.py
