# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

path="/content/drive/MyDrive/AudioPouring-master/audio_pouring"
os.chdir(path)

# !ls
# Out:
# assets	 demo.py      main_lstm.py  __pycache__        utils
# config	 __init__.py  model	    run_demo.ipynb     zhi-6.wav
# dataset  main_fc.py   pickle	    run_my_lstm.ipynb

# %%
# !python ./utils/generate_npy_list.py
# Out:
# save npy list in npy_train_4 to a npy file
# save npy list in npy_train_3 to a npy file
# save npy list in npy_train_1 to a npy file
# save npy list in npy_test_4 to a npy file
# save npy list in npy_test_3 to a npy file
# save npy list in npy_test_1 to a npy file
# save bottle 0 data
